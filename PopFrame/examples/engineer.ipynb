# %% [markdown]
# # Подготовка данных

# %%
import requests
import pandas as pd

res = requests.get('http://10.32.1.107:5300/api/v1/physical_object_types')
physical_objects_types = pd.DataFrame(res.json()).set_index('physical_object_type_id', drop=True)
# physical_objects_types.to_excel('pot.xlsx')
physical_objects_types
# Out:
#                                                                       name  \
# physical_object_type_id
# 1                                                       Рекреационная зона
# 2                                                            Водный объект
# 3                                                             Зеленая зона
# 4                                                                Жилой дом
# 5                                                           Нежилое здание
# 7                                                                 Площадка
# 8                                                      Заправочная станция
# 9                                                                 Памятник
# 10                                          Остановка наземного транспорта
# 11                                                                Кладбище
# 13                       Распределительный трубопровод для транспортиро...
# 14                                                Электрическая подстанция
# 18                                                Магистральный газопровод
# 19                                                                Парковка
# 20                                                   Линия электропередачи
# 21                                                          Электростанция
# 23                                                                 Зоопарк
# 24                                                      Сеть водоотведения
# 27                                                      Сеть водоснабжения
# 28                                                                    Порт
# 29                                                                   Склад
# 30                                                 Железнодорожная станция
# 31                                                                    Пляж
# 33                                                          Ветрогенератор
# 34                                                     Гидроэлектростанция
# 35                                                  Атомная электростанция
# 36                                                        Парк развлечений
# 37                                             Сооружение для очистки воды
# 38                                                      Водонапорная башня
# 39                                                 Водоочистное сооружение
# 40                                                 Водозаборное сооружение
# 41                                                               Котельная
# 42                                          Насосная станция водоснабжения
# 43                                                 Промышленная территория
# 44                                                                    Река
# 45                                                                   Озеро
# 46                                                                    Поле
# 47                                                       Травяное покрытие
# 48                                                                     Лес
# 49                                                             Полигон ТБО
# 50                                                      Федеральная дорога
# 51                                                     Региональная дорога
# 52                                                          Местная дорога
# 53                                                       Сеть электросвязи
#
#                                                   physical_object_function
# physical_object_type_id
# 1                                  {'id': 3, 'name': 'Рекреационная зона'}
# 2                                       {'id': 4, 'name': 'Водный объект'}
# 3                                        {'id': 2, 'name': 'Зеленая зона'}
# 4                                              {'id': 1, 'name': 'Здание'}
# 5                                              {'id': 1, 'name': 'Здание'}
# 7                                            {'id': 5, 'name': 'Площадка'}
# 8                                 {'id': 9, 'name': 'Заправочная станция'}
# 9                              {'id': 10, 'name': 'Достопримечательность'}
# 10                                          {'id': 8, 'name': 'Остановка'}
# 11                                 {'id': 3, 'name': 'Рекреационная зона'}
# 13                                   {'id': 15, 'name': 'Линейный объект'}
# 14                           {'id': 12, 'name': 'Объект электроснабжения'}
# 18                                   {'id': 15, 'name': 'Линейный объект'}
# 19                                           {'id': 5, 'name': 'Площадка'}
# 20                                   {'id': 15, 'name': 'Линейный объект'}
# 21                           {'id': 12, 'name': 'Объект электроснабжения'}
# 23                                   {'id': 6, 'name': 'Досуговый объект'}
# 24                              {'id': 14, 'name': 'Объект водоотведения'}
# 27                              {'id': 13, 'name': 'Объект водоснабжения'}
# 28                                          {'id': 8, 'name': 'Остановка'}
# 29                               {'id': 16, 'name': 'Промышленный объект'}
# 30                                          {'id': 8, 'name': 'Остановка'}
# 31                                 {'id': 3, 'name': 'Рекреационная зона'}
# 33                           {'id': 12, 'name': 'Объект электроснабжения'}
# 34                           {'id': 12, 'name': 'Объект электроснабжения'}
# 35                           {'id': 12, 'name': 'Объект электроснабжения'}
# 36                                   {'id': 6, 'name': 'Досуговый объект'}
# 37                              {'id': 14, 'name': 'Объект водоотведения'}
# 38                              {'id': 13, 'name': 'Объект водоснабжения'}
# 39                              {'id': 14, 'name': 'Объект водоотведения'}
# 40                              {'id': 13, 'name': 'Объект водоснабжения'}
# 41                             {'id': 11, 'name': 'Объект теплоснабжения'}
# 42                              {'id': 13, 'name': 'Объект водоснабжения'}
# 43                               {'id': 16, 'name': 'Промышленный объект'}
# 44                                      {'id': 4, 'name': 'Водный объект'}
# 45                                      {'id': 4, 'name': 'Водный объект'}
# 46                       {'id': 17, 'name': 'Сельскохозяйственный объект'}
# 47                                       {'id': 2, 'name': 'Зеленая зона'}
# 48                                       {'id': 2, 'name': 'Зеленая зона'}
# 49                                           {'id': 5, 'name': 'Площадка'}
# 50                                            {'id': 26, 'name': 'Дорога'}
# 51                                            {'id': 26, 'name': 'Дорога'}
# 52                                            {'id': 26, 'name': 'Дорога'}
# 53                                   {'id': 15, 'name': 'Линейный объект'}

# %%
from enum import Enum
class EngineeringObject(Enum):
    POWER_SUPPLY = 'Энергоснабжение'
    HEAT_SUPPLY = 'Теплоснабжение'
    GAS_SUPPLY = 'Газоснабжение'
    WATER_SUPPLY = 'Водоснабжение'
    WATER_DRAINAGE = 'Водоотведение'

# %%
ENG_OBJ = {
    EngineeringObject.POWER_SUPPLY: [14, 20, 21, 33, 34, 35],  # Электрические подстанции, ЛЭП, электростанции и генераторы
    EngineeringObject.HEAT_SUPPLY: [41],                       # Котельная
    EngineeringObject.GAS_SUPPLY: [13, 18],                    # Магистральный газопровод
    EngineeringObject.WATER_SUPPLY: [27, 38, 40, 42],          # Сети водоснабжения, водонапорные башни, водозаборные и насосные станции
    EngineeringObject.WATER_DRAINAGE: [24, 37, 39]             # Сети водоотведения, сооружения для очистки воды, водоочистные сооружения
}

# %%
import requests
import geopandas as gpd
import shapely
import json
import pandas as pd

URBAN_API = 'http://10.32.1.107:5300'
PAGE_SIZE = 10_000

def _get_physical_objects(region_id : int, pot_id : int, page : int, page_size : int = PAGE_SIZE):
  res = requests.get(f'{URBAN_API}/api/v1/territory/{region_id}/physical_objects_with_geometry', {
    'physical_object_type_id': pot_id,
    'page': page,
    'page_size': page_size,
  })
  return res.json()

def get_physical_objects(region_id : int, pot_id : int):
  page = 1
  results = []
  while True:
    res_json = _get_physical_objects(region_id, pot_id, page, page_size=PAGE_SIZE)
    results.extend(res_json['results'])
    if res_json['next'] is None:
      break
    page += 1
  
  # Фильтрация объектов с наличием geometry
  results_with_geometry = [result for result in results if 'geometry' in result and result['geometry'] is not None]
  
  # Если нет объектов с геометрией, возвращаем пустой GeoDataFrame
  if not results_with_geometry:
    return gpd.GeoDataFrame(columns=['geometry'])
  
  # Конвертация geometry
  for result in results_with_geometry:
    g = result['geometry']
    result['geometry'] = shapely.from_geojson(json.dumps(g))
  
  return gpd.GeoDataFrame(results_with_geometry).set_geometry('geometry')

def fetch_required_objects(region_id : int, pot_ids : list[int]):
  gdfs = [get_physical_objects(region_id, pot_id) for pot_id in pot_ids]
  return pd.concat(gdfs).set_geometry('geometry').set_crs(4326)

# %%
# def fetch_required_objects(region_id : int, pot_ids : list[int]):
#   gdfs = [get_physical_objects(region_id, pot_id) for pot_id in pot_ids]
#   return pd.concat(gdfs).set_geometry('geometry').set_crs(4326)

# gdf = fetch_required_objects(1, [4])
# gdf

# %%
gdfs = {}
for eng_obj, ind_id in ENG_OBJ.items():
  if len(ind_id) > 0:
    gdf = fetch_required_objects(1, ind_id)
    gdfs[eng_obj] = gdf
gdfs
# Out:
# {<EngineeringObject.POWER_SUPPLY: 'Энергоснабжение'>:                      geometry  physical_object_id  \
#  0   POINT (30.50513 59.84176)            759813.0
#  1   POINT (30.50316 59.84188)            759823.0
#  2    POINT (30.42919 60.0376)            759836.0
#  3   POINT (30.49322 59.89584)            759924.0
#  4   POINT (30.26719 60.11068)            759957.0
#  5   POINT (29.84225 59.87058)            759959.0
#  6   POINT (30.07734 59.77243)            759960.0
#  7   POINT (30.47855 59.90406)            759965.0
#  8   POINT (30.09877 59.78206)            759969.0
#  9     POINT (30.49359 59.939)            759973.0
#  10  POINT (30.48904 59.94282)            759984.0
#  11  POINT (30.48905 59.94284)            759990.0
#  12  POINT (30.48398 59.94375)            760001.0
#
#                                   physical_object_type  \
#  0   {'physical_object_type_id': 35, 'name': 'Атомн...
#  1   {'physical_object_type_id': 35, 'name': 'Атомн...
#  2   {'physical_object_type_id': 35, 'name': 'Атомн...
#  3   {'physical_object_type_id': 35, 'name': 'Атомн...
#  4   {'physical_object_type_id': 35, 'name': 'Атомн...
#  5   {'physical_object_type_id': 35, 'name': 'Атомн...
#  6   {'physical_object_type_id': 35, 'name': 'Атомн...
#  7   {'physical_object_type_id': 35, 'name': 'Атомн...
#  8   {'physical_object_type_id': 35, 'name': 'Атомн...
#  9   {'physical_object_type_id': 35, 'name': 'Атомн...
#  10  {'physical_object_type_id': 35, 'name': 'Атомн...
#  11  {'physical_object_type_id': 35, 'name': 'Атомн...
#  12  {'physical_object_type_id': 35, 'name': 'Атомн...
#
#                                 name address osm_id properties  \
#  0   (Physical object for (unnamed))    None   None         {}
#  1   (Physical object for (unnamed))    None   None         {}
#  2   (Physical object for (unnamed))    None   None         {}
#  3   (Physical object for (unnamed))    None   None         {}
#  4   (Physical object for (unnamed))    None   None         {}
#  5   (Physical object for (unnamed))    None   None         {}
#  6   (Physical object for (unnamed))    None   None         {}
#  7   (Physical object for (unnamed))    None   None         {}
#  8   (Physical object for (unnamed))    None   None         {}
#  9   (Physical object for (unnamed))    None   None         {}
#  10  (Physical object for (unnamed))    None   None         {}
#  11  (Physical object for (unnamed))    None   None         {}
#  12  (Physical object for (unnamed))    None   None         {}
#
#                                           centre_point  \
#  0   {'type': 'Point', 'coordinates': [30.5051266, ...
#  1   {'type': 'Point', 'coordinates': [30.5031632, ...
#  2   {'type': 'Point', 'coordinates': [30.4291869, ...
#  3   {'type': 'Point', 'coordinates': [30.4932235, ...
#  4   {'type': 'Point', 'coordinates': [30.2671947, ...
#  5   {'type': 'Point', 'coordinates': [29.8422486, ...
#  6   {'type': 'Point', 'coordinates': [30.077335, 5...
#  7   {'type': 'Point', 'coordinates': [30.4785509, ...
#  8   {'type': 'Point', 'coordinates': [30.0987739, ...
#  9   {'type': 'Point', 'coordinates': [30.4935943, ...
#  10  {'type': 'Point', 'coordinates': [30.4890427, ...
#  11  {'type': 'Point', 'coordinates': [30.4890493, ...
#  12  {'type': 'Point', 'coordinates': [30.4839848, ...
#
#                       created_at                   updated_at
#  0   2024-10-14T10:07:08.813499Z  2024-10-14T10:07:08.813499Z
#  1   2024-10-14T10:07:11.617739Z  2024-10-14T10:07:11.617739Z
#  2   2024-10-14T10:07:14.388877Z  2024-10-14T10:07:14.388877Z
#  3   2024-10-14T10:07:55.918200Z  2024-10-14T10:07:55.918200Z
#  4   2024-10-14T10:08:03.769546Z  2024-10-14T10:08:03.769546Z
#  5   2024-10-14T10:08:04.246719Z  2024-10-14T10:08:04.246719Z
#  6   2024-10-14T10:08:04.257549Z  2024-10-14T10:08:04.257549Z
#  7   2024-10-14T10:08:06.249964Z  2024-10-14T10:08:06.249964Z
#  8   2024-10-14T10:08:07.013439Z  2024-10-14T10:08:07.013439Z
#  9   2024-10-14T10:08:08.587837Z  2024-10-14T10:08:08.587837Z
#  10  2024-10-14T10:08:10.970553Z  2024-10-14T10:08:10.970553Z
#  11  2024-10-14T10:08:13.272154Z  2024-10-14T10:08:13.272154Z
#  12  2024-10-14T10:08:15.720084Z  2024-10-14T10:08:15.720084Z  ,
#  <EngineeringObject.HEAT_SUPPLY: 'Теплоснабжение'>: Empty GeoDataFrame
#  Columns: [geometry]
#  Index: [],
#  <EngineeringObject.GAS_SUPPLY: 'Газоснабжение'>: Empty GeoDataFrame
#  Columns: [geometry]
#  Index: [],
#  <EngineeringObject.WATER_SUPPLY: 'Водоснабжение'>:                     geometry  physical_object_id  \
#  0  POINT (30.13191 59.79087)            760454.0
#  1  POINT (30.50604 59.83011)            760457.0
#  2  POINT (30.50604 59.83013)            760467.0
#  3  POINT (30.27754 59.70902)            760468.0
#
#                                  physical_object_type  \
#  0  {'physical_object_type_id': 38, 'name': 'Водон...
#  1  {'physical_object_type_id': 38, 'name': 'Водон...
#  2  {'physical_object_type_id': 38, 'name': 'Водон...
#  3  {'physical_object_type_id': 38, 'name': 'Водон...
#
#                                name address osm_id properties  \
#  0  (Physical object for (unnamed))    None   None         {}
#  1  (Physical object for (unnamed))    None   None         {}
#  2  (Physical object for (unnamed))    None   None         {}
#  3  (Physical object for (unnamed))    None   None         {}
#
#                                          centre_point  \
#  0  {'type': 'Point', 'coordinates': [30.1319126, ...
#  1  {'type': 'Point', 'coordinates': [30.5060413, ...
#  2  {'type': 'Point', 'coordinates': [30.5060351, ...
#  3  {'type': 'Point', 'coordinates': [30.2775366, ...
#
#                      created_at                   updated_at
#  0  2024-10-14T10:10:41.528616Z  2024-10-14T10:10:41.528616Z
#  1  2024-10-14T10:10:41.605356Z  2024-10-14T10:10:41.605356Z
#  2  2024-10-14T10:10:44.243573Z  2024-10-14T10:10:44.243573Z
#  3  2024-10-14T10:10:46.114201Z  2024-10-14T10:10:46.114201Z  ,
#  <EngineeringObject.WATER_DRAINAGE: 'Водоотведение'>:                                             geometry  physical_object_id  \
#  0  POLYGON ((30.06831 59.81601, 30.06829 59.81597...            760612.0
#
#                                  physical_object_type  \
#  0  {'physical_object_type_id': 39, 'name': 'Водоо...
#
#                                name address osm_id properties  \
#  0  (Physical object for (unnamed))    None   None         {}
#
#                                          centre_point  \
#  0  {'type': 'Point', 'coordinates': [30.067854313...
#
#                      created_at                   updated_at
#  0  2024-10-14T10:11:29.293160Z  2024-10-14T10:11:29.293160Z  }

# %%
def get_engineering_gdf(data_dict: dict) -> gpd.GeoDataFrame:
    combined_gdf = gpd.GeoDataFrame(columns=['type', 'geometry'], crs="EPSG:4326")

    for eng_obj, gdf in data_dict.items():
        gdf = gdf.copy()  
        gdf['type'] = eng_obj.value 
        combined_gdf = pd.concat([combined_gdf, gdf], ignore_index=True)

    combined_gdf = gpd.GeoDataFrame(combined_gdf, geometry='geometry', crs="EPSG:4326")
    return combined_gdf

# %%
combined_gdf = get_engineering_gdf(gdfs)
combined_gdf
# Out:
#                type                                           geometry  \
# 0   Энергоснабжение                          POINT (30.50513 59.84176)
# 1   Энергоснабжение                          POINT (30.50316 59.84188)
# 2   Энергоснабжение                           POINT (30.42919 60.0376)
# 3   Энергоснабжение                          POINT (30.49322 59.89584)
# 4   Энергоснабжение                          POINT (30.26719 60.11068)
# 5   Энергоснабжение                          POINT (29.84225 59.87058)
# 6   Энергоснабжение                          POINT (30.07734 59.77243)
# 7   Энергоснабжение                          POINT (30.47855 59.90406)
# 8   Энергоснабжение                          POINT (30.09877 59.78206)
# 9   Энергоснабжение                            POINT (30.49359 59.939)
# 10  Энергоснабжение                          POINT (30.48904 59.94282)
# 11  Энергоснабжение                          POINT (30.48905 59.94284)
# 12  Энергоснабжение                          POINT (30.48398 59.94375)
# 13    Водоснабжение                          POINT (30.13191 59.79087)
# 14    Водоснабжение                          POINT (30.50604 59.83011)
# 15    Водоснабжение                          POINT (30.50604 59.83013)
# 16    Водоснабжение                          POINT (30.27754 59.70902)
# 17    Водоотведение  POLYGON ((30.06831 59.81601, 30.06829 59.81597...
#
#     physical_object_id                               physical_object_type  \
# 0             759813.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 1             759823.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 2             759836.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 3             759924.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 4             759957.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 5             759959.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 6             759960.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 7             759965.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 8             759969.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 9             759973.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 10            759984.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 11            759990.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 12            760001.0  {'physical_object_type_id': 35, 'name': 'Атомн...
# 13            760454.0  {'physical_object_type_id': 38, 'name': 'Водон...
# 14            760457.0  {'physical_object_type_id': 38, 'name': 'Водон...
# 15            760467.0  {'physical_object_type_id': 38, 'name': 'Водон...
# 16            760468.0  {'physical_object_type_id': 38, 'name': 'Водон...
# 17            760612.0  {'physical_object_type_id': 39, 'name': 'Водоо...
#
#                                name address osm_id properties  \
# 0   (Physical object for (unnamed))    None   None         {}
# 1   (Physical object for (unnamed))    None   None         {}
# 2   (Physical object for (unnamed))    None   None         {}
# 3   (Physical object for (unnamed))    None   None         {}
# 4   (Physical object for (unnamed))    None   None         {}
# 5   (Physical object for (unnamed))    None   None         {}
# 6   (Physical object for (unnamed))    None   None         {}
# 7   (Physical object for (unnamed))    None   None         {}
# 8   (Physical object for (unnamed))    None   None         {}
# 9   (Physical object for (unnamed))    None   None         {}
# 10  (Physical object for (unnamed))    None   None         {}
# 11  (Physical object for (unnamed))    None   None         {}
# 12  (Physical object for (unnamed))    None   None         {}
# 13  (Physical object for (unnamed))    None   None         {}
# 14  (Physical object for (unnamed))    None   None         {}
# 15  (Physical object for (unnamed))    None   None         {}
# 16  (Physical object for (unnamed))    None   None         {}
# 17  (Physical object for (unnamed))    None   None         {}
#
#                                          centre_point  \
# 0   {'type': 'Point', 'coordinates': [30.5051266, ...
# 1   {'type': 'Point', 'coordinates': [30.5031632, ...
# 2   {'type': 'Point', 'coordinates': [30.4291869, ...
# 3   {'type': 'Point', 'coordinates': [30.4932235, ...
# 4   {'type': 'Point', 'coordinates': [30.2671947, ...
# 5   {'type': 'Point', 'coordinates': [29.8422486, ...
# 6   {'type': 'Point', 'coordinates': [30.077335, 5...
# 7   {'type': 'Point', 'coordinates': [30.4785509, ...
# 8   {'type': 'Point', 'coordinates': [30.0987739, ...
# 9   {'type': 'Point', 'coordinates': [30.4935943, ...
# 10  {'type': 'Point', 'coordinates': [30.4890427, ...
# 11  {'type': 'Point', 'coordinates': [30.4890493, ...
# 12  {'type': 'Point', 'coordinates': [30.4839848, ...
# 13  {'type': 'Point', 'coordinates': [30.1319126, ...
# 14  {'type': 'Point', 'coordinates': [30.5060413, ...
# 15  {'type': 'Point', 'coordinates': [30.5060351, ...
# 16  {'type': 'Point', 'coordinates': [30.2775366, ...
# 17  {'type': 'Point', 'coordinates': [30.067854313...
#
#                      created_at                   updated_at
# 0   2024-10-14T10:07:08.813499Z  2024-10-14T10:07:08.813499Z
# 1   2024-10-14T10:07:11.617739Z  2024-10-14T10:07:11.617739Z
# 2   2024-10-14T10:07:14.388877Z  2024-10-14T10:07:14.388877Z
# 3   2024-10-14T10:07:55.918200Z  2024-10-14T10:07:55.918200Z
# 4   2024-10-14T10:08:03.769546Z  2024-10-14T10:08:03.769546Z
# 5   2024-10-14T10:08:04.246719Z  2024-10-14T10:08:04.246719Z
# 6   2024-10-14T10:08:04.257549Z  2024-10-14T10:08:04.257549Z
# 7   2024-10-14T10:08:06.249964Z  2024-10-14T10:08:06.249964Z
# 8   2024-10-14T10:08:07.013439Z  2024-10-14T10:08:07.013439Z
# 9   2024-10-14T10:08:08.587837Z  2024-10-14T10:08:08.587837Z
# 10  2024-10-14T10:08:10.970553Z  2024-10-14T10:08:10.970553Z
# 11  2024-10-14T10:08:13.272154Z  2024-10-14T10:08:13.272154Z
# 12  2024-10-14T10:08:15.720084Z  2024-10-14T10:08:15.720084Z
# 13  2024-10-14T10:10:41.528616Z  2024-10-14T10:10:41.528616Z
# 14  2024-10-14T10:10:41.605356Z  2024-10-14T10:10:41.605356Z
# 15  2024-10-14T10:10:44.243573Z  2024-10-14T10:10:44.243573Z
# 16  2024-10-14T10:10:46.114201Z  2024-10-14T10:10:46.114201Z
# 17  2024-10-14T10:11:29.293160Z  2024-10-14T10:11:29.293160Z

# %%
combined_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86669fd277782cd506573e32f760e6f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86669fd277782cd506573e32f760e6f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86669fd277782cd506573e32f760e6f0 = L.map(
#                 &quot;map_86669fd277782cd506573e32f760e6f0&quot;,
#                 {
#                     center: [59.909853600000005, 30.17414495],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_86669fd277782cd506573e32f760e6f0);
#
#
#
#
#
#             var tile_layer_49aeb45e7e5583ff0ef3e705b29d764a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86669fd277782cd506573e32f760e6f0);
#
#
#             map_86669fd277782cd506573e32f760e6f0.fitBounds(
#                 [[59.7090247, 29.8422486], [60.1106825, 30.5060413]],
#                 {}
#             );
#
#
#         function geo_json_61fa068f6f9a3dd297cbe638737730c6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_61fa068f6f9a3dd297cbe638737730c6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_61fa068f6f9a3dd297cbe638737730c6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_61fa068f6f9a3dd297cbe638737730c6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_61fa068f6f9a3dd297cbe638737730c6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_61fa068f6f9a3dd297cbe638737730c6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_61fa068f6f9a3dd297cbe638737730c6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_61fa068f6f9a3dd297cbe638737730c6 = L.geoJson(null, {
#                 onEachFeature: geo_json_61fa068f6f9a3dd297cbe638737730c6_onEachFeature,
#
#                 style: geo_json_61fa068f6f9a3dd297cbe638737730c6_styler,
#                 pointToLayer: geo_json_61fa068f6f9a3dd297cbe638737730c6_pointToLayer
#         });
#
#         function geo_json_61fa068f6f9a3dd297cbe638737730c6_add (data) {
#             geo_json_61fa068f6f9a3dd297cbe638737730c6
#                 .addData(data)
#                 .addTo(map_86669fd277782cd506573e32f760e6f0);
#         }
#             geo_json_61fa068f6f9a3dd297cbe638737730c6_add({&quot;bbox&quot;: [29.8422486, 59.7090247, 30.5060413, 60.1106825], &quot;features&quot;: [{&quot;bbox&quot;: [30.5051266, 59.8417642, 30.5051266, 59.8417642], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.5051266, 59.8417642], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;address&quot;: null, &quot;centre_point&quot;: &quot;{\u0027type\u0027: \u0027Point\u0027, \u0027coordinates\u0027: [30.5051266, 59.8417642]}&quot;, &quot;created_at&quot;: &quot;2024-10-14T10:07:08.813499Z&quot;, &quot;name&quot;: &quot;(Physical object for (unnamed))&quot;, &quot;osm_id&quot;: null, &quot;physical_object_id&quot;: 759813

# %%
spb_hex = gpd.read_file('data/spb_hex.geojson')
spb_hex
# Out:
#                                               geometry
# 0    POLYGON ((30.12453 60.01677, 30.14338 60.01106...
# 1    POLYGON ((30.23961 60.09269, 30.2585 60.08696,...
# 2    POLYGON ((30.40522 59.85712, 30.42398 59.85134...
# 3    POLYGON ((30.19969 59.98166, 30.21852 59.97593...
# 4    POLYGON ((30.3715 60.04029, 30.39036 60.03454,...
# ..                                                 ...
# 611  POLYGON ((30.3081 59.72653, 30.3268 59.72075, ...
# 612  POLYGON ((30.26976 59.689, 30.28843 59.68323, ...
# 613  POLYGON ((30.27763 60.09348, 30.29652 60.08775...
# 614  POLYGON ((30.06399 59.73999, 30.08269 59.73426...
# 615  POLYGON ((30.04687 59.8682, 30.06564 59.86248,...
#
# [616 rows x 1 columns]

# %% [markdown]
# # РАБОТАЕМ

# %%
from popframe.method.engineer import InfrastructureAnalyzer

analyzer = InfrastructureAnalyzer(combined_gdf, spb_hex)
results = analyzer.get_results()
results
# Out:
#      score                   types_in_radius  \
# 0        1                 [Энергоснабжение]
# 1        1                 [Энергоснабжение]
# 2        1                 [Энергоснабжение]
# 3        1                 [Энергоснабжение]
# 4        1                 [Энергоснабжение]
# ..     ...                               ...
# 611      1                 [Энергоснабжение]
# 612      2  [Водоснабжение, Энергоснабжение]
# 613      1                 [Энергоснабжение]
# 614      1                 [Энергоснабжение]
# 615      1                 [Энергоснабжение]
#
#                                               geometry
# 0    POLYGON ((30.12453 60.01677, 30.14338 60.01106...
# 1    POLYGON ((30.23961 60.09269, 30.2585 60.08696,...
# 2    POLYGON ((30.40522 59.85712, 30.42398 59.85134...
# 3    POLYGON ((30.19969 59.98166, 30.21852 59.97593...
# 4    POLYGON ((30.3715 60.04029, 30.39036 60.03454,...
# ..                                                 ...
# 611  POLYGON ((30.3081 59.72653, 30.3268 59.72075, ...
# 612  POLYGON ((30.26976 59.689, 30.28843 59.68323, ...
# 613  POLYGON ((30.27763 60.09348, 30.29652 60.08775...
# 614  POLYGON ((30.06399 59.73999, 30.08269 59.73426...
# 615  POLYGON ((30.04687 59.8682, 30.06564 59.86248,...
#
# [616 rows x 3 columns]

# %%
results[results['score']>1]
# Out:
#      score                   types_in_radius  \
# 75       2  [Водоснабжение, Энергоснабжение]
# 200      2  [Водоснабжение, Энергоснабжение]
# 212      2  [Водоснабжение, Энергоснабжение]
# 429      2  [Энергоснабжение, Водоотведение]
# 527      2  [Водоснабжение, Энергоснабжение]
# 532      2  [Водоснабжение, Энергоснабжение]
# 537      2  [Энергоснабжение, Водоотведение]
# 612      2  [Водоснабжение, Энергоснабжение]
#
#                                               geometry
# 75   POLYGON ((30.1021 59.77753, 30.12082 59.7718, ...
# 200  POLYGON ((30.25131 59.70704, 30.27 59.70127, 3...
# 212  POLYGON ((30.12118 59.79631, 30.13991 59.79057...
# 429  POLYGON ((30.02734 59.81268, 30.04608 59.80696...
# 527  POLYGON ((30.13972 59.77832, 30.15844 59.77258...
# 532  POLYGON ((30.47995 59.82172, 30.49869 59.81593...
# 537  POLYGON ((30.06498 59.81349, 30.08372 59.80777...
# 612  POLYGON ((30.26976 59.689, 30.28843 59.68323, ...
